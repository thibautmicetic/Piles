# %%
class Pile:
    def __init__(self):
        mapile = []
        
    def __str__(self):
        return str(self._mapile)[:-1] + "<"
    
    def __len__(self):
        return len(self.mapile)
    
    def sommet(self):
        if self.mapile > 0:
            return self.mapile[-1]
    
    def empiler(self):
        self.mapile += [contenu]
        
    def depiler(self):
        if len(self) > 0:
            return self.mapile.pop()
