# %%
class Pile:
    def __init__(self):
        self._mapile = []
    
    def __len__(self):
        return len(self._mapile)
    
    def sommet(self, e):
        if len(self) > 0:
            return self._mapile[0]
        
    def empiler(self, e):
        self._mapile = [e] + self._mapile
        
    def depiler(self, e):
        if len(self) > 0:
            return self._mafile.pop(0)
        
def est_bien_parenthesee(expression):
    """Renvoie un booléen de parenthésage correct
    
    :param expression: calcul parenthésée
    :type expression: str
    """
    ma_pile = Pile()
    valide = True
    while valide and i < len(expression):
        caractere = expression[i]
        if caractere == '([{':
            ma_pile.empiler(caractere)
        elif caractere == ')':
            valide = ma_pile.depiler() == "("
        elif caractere == ']':
            valide = ma_pile.depiler() == "["
        elif caractere == '}':
            valide = ma_pile.depiler() == "{"
            
        i += 1
        
    return valide and len(ma_pile) == 0

expressions = ["[2+(2-3x)]", "2+(2x-3)"]
